# %%
# coding: utf-8
#------------------------------------------------------------------------------
# Importer les packages et modules utiles
#------------------------------------------------------------------------------
from __future__ import division
import os
import pandas as pd
from run.fonctions_outils.load_file import main as load_file
from run.fonctions_outils.do_lda import main as do_lda
from run.fonctions_outils.stats_descs import stats_descs
from run.fonctions_outils.stats_descs import stats_tags
from run.fonctions_outils.kw_tag import main as kw_tag
from run.fonctions_outils.emoji_tag import main as emoji_tag
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-88a8f12a37cf> in <module>()
#       6 import os
#       7 import pandas as pd
# ----> 8 from run.fonctions_outils.load_file import main as load_file
#       9 from run.fonctions_outils.do_lda import main as do_lda
#      10 from run.fonctions_outils.stats_descs import stats_descs
#
# ModuleNotFoundError: No module named 'run.fonctions_outils'; 'run' is not a package

# %%
from run.fonctions_outils.load_file import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-95f8790c2ba2> in <module>()
# ----> 1 from run.fonctions_outils.load_file import *
#
# ModuleNotFoundError: No module named 'run.fonctions_outils'; 'run' is not a package

# %%
import sys
print(sys.version)
# Out:
# 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
